# %%
import pandas as pd
from config.config import *

# %%
flan_df = pd.read_pickle(os.path.join(OBTAINED_DATA, 'test_df_flan-t5-predicted.pkl'))

# %%
flan_df
# Out:
#                                           sentence_text  \
# 404   book man bashing book uplifting book women cau...
# 345   vicar saw named Angela Diabola   means angel d...
# 2296          story middle school aged kid named Arthur
# 1723  Seventh Tower book written younger readers Abh...
# 51                 Capone classic true crime literature
# ...                                                 ...
# 286   Overall series gets 4 stars individual assessm...
# 2418  asthma attack successfully helps readers sympa...
# 1284    Wonderful stuff constantly happens disjointe...
# 826   affection Tony Hill Carol Jordan created Val M...
# 781                               Jack sane losing mind
#
#                                             targets  targets_num  \
# 404                       [women, cautionairy tale]            2
# 345                                [vicar, Diabola]            2
# 2296               [middle school aged kid, Arthur]            2
# ...
